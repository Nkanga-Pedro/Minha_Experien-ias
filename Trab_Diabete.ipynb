# %% [markdown]
# <a href="https://colab.research.google.com/github/Nkanga-Pedro/Minha_Experien-ias/blob/main/Trab_Diabete.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
dado = pd.read_table('indios_pima.txt')

# %%
dado.head()
# Out:
#    NPreg  Plasma  Diast  Triceps  Serum   BMI  Pedig  Age  Class
# 0      6     148     72       35      0  33.6  0.627   50      1
# 1      1      85     66       29      0  26.6  0.351   31      0
# 2      8     183     64        0      0  23.3  0.672   32      1
# 3      1      89     66       23     94  28.1  0.167   21      0
# 4      0     137     40       35    168  43.1  2.288   33      1

# %%
dado.describe
# Out:
# <bound method NDFrame.describe of      NPreg  Plasma  Diast  Triceps  Serum   BMI  Pedig  Age  Class
# 0        6     148     72       35      0  33.6  0.627   50      1
# 1        1      85     66       29      0  26.6  0.351   31      0
# 2        8     183     64        0      0  23.3  0.672   32      1
# 3        1      89     66       23     94  28.1  0.167   21      0
# 4        0     137     40       35    168  43.1  2.288   33      1
# ..     ...     ...    ...      ...    ...   ...    ...  ...    ...
# 763     10     101     76       48    180  32.9  0.171   63      0
# 764      2     122     70       27      0  36.8  0.340   27      0
# 765      5     121     72       23    112  26.2  0.245   30      0
# 766      1     126     60        0      0  30.1  0.349   47      1
# 767      1      93     70       31      0  30.4  0.315   23      0
#
# [768 rows x 9 columns]>

# %%
dado.shape
# Out:
# (768, 9)

# %%
dado['Class'].unique
# Out:
# <bound method Series.unique of 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Class, Length: 768, dtype: int64>

# %%
dado.groupby('Class').size()
# Out:
# Class
# 0    500
# 1    268
# dtype: int64

# %%
import seaborn as sns
sns.countplot(dado['Class'],label="Count")
plt.show()
# Out:
# C:\Users\Gebruiker\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import seaborn as sns
sns.countplot(dado['Age'],label="Count")
plt.show()
# Out:
# C:\Users\Gebruiker\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(15,10))    
plt.subplot(2,2,1)
sns.boxplot(x='Class',y='NPreg',data=dado)    
plt.subplot(2,2,2)    
sns.boxplot(x='Class',y='Plasma',data=dado)    
plt.subplot(2,2,3)    
sns.boxplot(x='Class',y='Diast',data=dado)    
plt.subplot(2,2,4)    
sns.boxplot(x='Class',y='Triceps',data=dado)
plt.subplot(2,2,4)    
sns.boxplot(x='Class',y='Triceps',data=dado)
#Serum	BMI	Pedig	Age
# Out:
# <AxesSubplot:xlabel='Class', ylabel='Triceps'>
